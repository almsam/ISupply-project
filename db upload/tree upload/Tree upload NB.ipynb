# %% [markdown]
# # Uploading more stuff
#
#     Preparations: you know the drill by now

# %%
import pandas as pd
import psycopg2

# %%
con = psycopg2.connect(database="iSupply",
                        host="38.180.117.52",
                        user="postgres",
                        password="deerRun",
                        port="5432")
cursor = con.cursor()

cursor.close()
con.close()

# %% [markdown]
#     For this phase, we will need to read, so lets get that done

# %%
con = psycopg2.connect(database="iSupply", host="38.180.117.52", user="postgres", password="deerRun", port="5432"); cursor = con.cursor()

cursor.execute("""select * from "Categories" c""")
out = cursor.fetchall(); print(out)

cursor.close(); con.close()
# Out:
# [(1, 'Agriculture'), (2, 'Agricultural Equipment'), (3, 'Agricultural Greenhouses'), (4, 'Aquaculture Equipment'), (5, 'Aquaculture Trap'), (6, 'Fishing Float'), (7, 'Fishing Net'), (8, 'Fishing Rope'), (9, 'Other Aquaculture Equipment'), (10, 'Ear Tag'), (11, 'Agricultural Growing Media'), (12, 'Peat'), (13, 'Agricultural Product Stock'), (14, 'Agricultural Waste'), (15, 'Animal Extract'), (16, 'Animal Feed'), (17, 'Animal Products'), (18, 'Eggs'), (19, 'Fowl & Livestock'), (20, 'Bamboo Raw Materials'), (21, 'Bean-Like Seeds'), (22, 'Cacao'), (23, 'Coffee Beans'), (24, 'Vanilla Beans'), (25, 'Beans'), (26, 'Broad Beans'), (27, 'Butter Beans'), (28, 'Chickpeas'), (29, 'Kidney Beans'), (30, 'Lentils'), (31, 'Lima Beans'), (32, 'Other Beans'), (33, 'Peas'), (34, 'Soybeans'), (35, 'Vigna Beans'), (36, 'Cigarettes'), (37, 'Cigars'), (38, 'Fresh Fruit'), (39, 'Fresh Apples'), (40, 'Fresh Apricots'), (41, 'Fresh Avocados'), (42, 'Fresh Bananas'), (43, 'Fresh Berries'), (44, 'Fresh Cherries'), (45, 'Fresh Citrus Fruit'), (46, 'Fresh Coconuts'), (47, 'Fresh Dragon Fruit'), (48, 'Fresh Durians'), (49, 'Fresh Grapes'), (50, 'Fresh Guava'), (51, 'Fresh Kiwi Fruit'), (52, 'Fresh Mangos'), (53, 'Fresh Melons'), (54, 'Fresh Olives'), (55, 'Fresh Papaya'), (56, 'Fresh Peaches'), (57, 'Fresh Pears'), (58, 'Fresh Pineapples'), (59, 'Fresh Plums'), (60, 'Fresh Pomegranates'), (61, 'Other Fresh Fruit'), (62, 'Fresh Vegetables'), (63, 'Fresh Asparagus'), (64, 'Fresh Broccoli'), (65, 'Fresh Burdock'), (66, 'Fresh Cabbages'), (67, 'Fresh Capsicum'), (68, 'Fresh Carrots'), (69, 'Fresh Cassava'), (70, 'Fresh Cauliflower'), (71, 'Fresh Celery Cabbage'), (72, 'Fresh Cucumber'), (73, 'Fresh Garlic'), (74, 'Fresh Ginger'), (75, 'Fresh Okra'), (76, 'Fresh Onions'), (77, 'Fresh Potatoes'), (78, 'Fresh Pumpkins'), (79, 'Fresh Radish'), (80, 'Fresh Scallions'), (81, 'Fresh Sweet Potatoes'), (82, 'Fresh Taro'), (83, 'Fresh Tomatoes'), (84, 'Other Fresh Vegetables'), (85, 'Grain'), (86, 'Barley'), (87, 'Buckwheat'), (88, 'Corn'), (89, 'Millet'), (90, 'Oats'), (91, 'Other Grain'), (92, 'Quinoa'), (93, 'Rice'), (94, 'Rye'), (95, 'Sorghum'), (96, 'Wheat'), (97, 'Logs'), (98, 'Mushrooms & Truffles'), (99, 'Mushrooms'), (100, 'Truffles'), (101, 'Nuts & Kernels'), (102, 'Almond'), (103, 'Apricot Kernels'), (104, 'Betel Nuts'), (105, 'Brazil Nuts'), (106, 'Cashew Nuts'), (107, 'Chestnuts'), (108, 'Ginkgo Nuts'), (109, 'Hazelnuts'), (110, 'Macadamia Nuts'), (111, 'Melon Seeds'), (112, 'Other Nuts & Kernels'), (113, 'Peanuts'), (114, 'Pecan Nuts'), (115, 'Pine Nuts'), (116, 'Pistachio Nuts'), (117, 'Pumpkin Kernels'), (118, 'Sunflower Kernels'), (119, 'Walnuts'), (120, 'Ornamental Plants'), (121, 'Bonsai'), (122, 'Dried Flowers'), (123, 'Fresh Cut Flowers'), (124, 'Natural Plants'), (125, 'Other Agriculture Products'), (126, 'Plant & Animal Oil'), (127, 'Animal Oil'), (128, 'Blended Oil'), (129, 'Camellia Oil'), (130, 'Castor Oil'), (131, 'Coconut Oil'), (132, 'Corn Oil'), (133, 'Ginger Oil'), (134, 'Olive Oil'), (135, 'Other Plant & Animal Oil'), (136, 'Palm Oil'), (137, 'Rapeseed Oil'), (138, 'Sesame Oil'), (139, 'Soybean Oil'), (140, 'Sunflower Oil'), (141, 'Plant Extract'), (152, 'Apparel'), (153, 'Apparel Design Services'), (154, 'Apparel Processing Services'), (155, 'Apparel Stock'), (156, "Children\\'s Clothing"), (157, "Children\\'s Clothing Sets"), (158, "Children\\'s Coats"), (159, "Children\\'s Hoodies & Sweatshirts"), (160, "Children\\'s Jackets"), (161, "Children\\'s Jeans"), (162, "Children\\'s Pants & Trousers"), (163, "Children\\'s Shirts & Tops"), (164, "Children\\'s Shorts"), (165, "Children\\'s Sweaters"), (166, "Children\\'s T-Shirts"), (167, "Children\\'s Underwear"), (168, "Children\\'s Vests & Waistcoats"), (169, "Girls\\' Dresses"), (170, "Girls\\' Skirts"), (171, "Other Children\\'s Clothing"), (172, 'Coats'), (173, 'Costumes'), (174, 'Anime Costumes'), (175, 'Mascot'), (176, 'Other Costumes'), (177, 'Reenactment Attire'), (178, 'Sexy Costumes' ...

# %% [markdown]
#     Now lets make this usable

# %%
df = pd.DataFrame(out, columns=['ser', 'cat']); print(df)
# Out:
#        ser                       cat
# 0        1               Agriculture
# 1        2    Agricultural Equipment
# 2        3  Agricultural Greenhouses
# 3        4     Aquaculture Equipment
# 4        5          Aquaculture Trap
# ...    ...                       ...
# 4147  4592            Truck Steering
# 4148  4593          Truck Suspension
# 4149  4594                Truck Tire
# 4150  4595        Truck Transmission
# 4151  4596               Truck Wheel
#
# [4152 rows x 2 columns]

# %%
df.head(15)
# Out:
#     ser                          cat
# 0     1                  Agriculture
# 1     2       Agricultural Equipment
# 2     3     Agricultural Greenhouses
# 3     4        Aquaculture Equipment
# 4     5             Aquaculture Trap
# 5     6                Fishing Float
# 6     7                  Fishing Net
# 7     8                 Fishing Rope
# 8     9  Other Aquaculture Equipment
# 9    10                      Ear Tag
# 10   11   Agricultural Growing Media
# 11   12                         Peat
# 12   13   Agricultural Product Stock
# 13   14           Agricultural Waste
# 14   15               Animal Extract

# %% [markdown]
#     Now the next step is to take our tree from slimtree.xlsx, convert all pointers in the dataset from cat to ser (so the DB can eat them as int), & upload it

# %%
dfT = pd.read_excel("slimTree.xlsx")
dfT.head(15)
# Out:
#                     category               subcategory
# 0                Agriculture    Agricultural Equipment
# 1     Agricultural Equipment  Agricultural Greenhouses
# 2   Agricultural Greenhouses                       NaN
# 3                Agriculture    Agricultural Equipment
# 4     Agricultural Equipment     Aquaculture Equipment
# 5      Aquaculture Equipment                       NaN
# 6                Agriculture    Agricultural Equipment
# 7     Agricultural Equipment     Aquaculture Equipment
# 8      Aquaculture Equipment          Aquaculture Trap
# 9                Agriculture    Agricultural Equipment
# 10    Agricultural Equipment     Aquaculture Equipment
# 11     Aquaculture Equipment             Fishing Float
# 12               Agriculture    Agricultural Equipment
# 13    Agricultural Equipment     Aquaculture Equipment
# 14     Aquaculture Equipment               Fishing Net

# %% [markdown]
#     Lets start by casting -1 to all leafs

# %%
dfT.fillna('-1', inplace=True); dfT.head(15)
# Out:
#                     category               subcategory
# 0                Agriculture    Agricultural Equipment
# 1     Agricultural Equipment  Agricultural Greenhouses
# 2   Agricultural Greenhouses                        -1
# 3                Agriculture    Agricultural Equipment
# 4     Agricultural Equipment     Aquaculture Equipment
# 5      Aquaculture Equipment                        -1
# 6                Agriculture    Agricultural Equipment
# 7     Agricultural Equipment     Aquaculture Equipment
# 8      Aquaculture Equipment          Aquaculture Trap
# 9                Agriculture    Agricultural Equipment
# 10    Agricultural Equipment     Aquaculture Equipment
# 11     Aquaculture Equipment             Fishing Float
# 12               Agriculture    Agricultural Equipment
# 13    Agricultural Equipment     Aquaculture Equipment
# 14     Aquaculture Equipment               Fishing Net

# %% [markdown]
#     & then lets try replacing everything where needed

# %%
map_dic = df.set_index('cat')['ser'].to_dict()

dfInt = pd.DataFrame(dfT)

dfInt['category']    = dfInt['category']   .map(map_dic).fillna(-1).astype(int)
dfInt['subcategory'] = dfInt['subcategory'].map(map_dic).fillna(-1).astype(int)

dfInt.head(15)
# Out:
#     category  subcategory
# 0          1            2
# 1          2            3
# 2          3           -1
# 3          1            2
# 4          2            4
# 5          4           -1
# 6          1            2
# 7          2            4
# 8          4            5
# 9          1            2
# 10         2            4
# 11         4            6
# 12         1            2
# 13         2            4
# 14         4            7

# %% [markdown]
#     Cautious optimism time, lets investigate it

# %%
dfInt.iloc[0:10]
# Out:
#    category  subcategory
# 0         1            2
# 1         2            3
# 2         3           -1
# 3         1            2
# 4         2            4
# 5         4           -1
# 6         1            2
# 7         2            4
# 8         4            5
# 9         1            2

# %%
dfInt.iloc[100:110]
# Out:
#      category  subcategory
# 100        36           35
# 101        35           -1
# 102         1           37
# 103        37           35
# 104        35           -1
# 105         1           38
# 106        38           35
# 107        35           -1
# 108         1           38
# 109        38           39

# %%
dfInt.iloc[1000:1100]
# Out:
#       category  subcategory
# 1000       328           -1
# 1001        -1           -1
# 1002       152          328
# 1003       328           -1
# 1004        -1           -1
# ...        ...          ...
# 1095        -1          367
# 1096       367          368
# 1097       368           -1
# 1098        -1          367
# 1099       367          369
#
# [100 rows x 2 columns]

# %%
dfInt.iloc[4500:4510]
# Out:
#       category  subcategory
# 4500        -1         1496
# 4501      1496         1500
# 4502      1500           -1
# 4503        -1         1496
# 4504      1496         1500
# 4505      1500           -1
# 4506        -1         1496
# 4507      1496         1500
# 4508      1500           -1
# 4509        -1         1496

# %%
print("The dataframe has ", dfInt.size, " entries")
# Out:
# The dataframe has  27564  entries

# %% [markdown]
#     Looking good, lets release the repeats

# %%
dfIntUnique = pd.DataFrame(dfInt.drop_duplicates())
dfIntUnique.head(15)
# Out:
#     category  subcategory
# 0          1            2
# 1          2            3
# 2          3           -1
# 4          2            4
# 5          4           -1
# 8          4            5
# 11         4            6
# 14         4            7
# 17         4            8
# 20         4            9
# 22         2           10
# 23        10           -1
# 24         1           11
# 25        11           10
# 28        11           12

# %%
print("Now the dataframe has ", dfIntUnique.size, " entries")
# Out:
# Now the dataframe has  15400  entries

# %% [markdown]
#     Perfect, do I dare try to upload this? Lets check for issues first

# %%
def is_not_int(val):
    return not isinstance(val, int)

non_int_mask = dfIntUnique.map(is_not_int)
non_int_locations = dfIntUnique[non_int_mask]

print("Non ints are at:"); print(non_int_locations.dropna())
# Out:
# Non ints are at:
# Empty DataFrame
# Columns: [category, subcategory]
# Index: []

# %% [markdown]
#     My favorite part was when they said ITS UPLOADING TIME & uploaded all over the place

# %%
def get_category_subcategory(df, index):
    parent = df.loc[index, "category"]                                                                                  # O( log(n) )
    child = df.loc[index, "subcategory"]
    return parent, child


def process_categories(df, cursor, con, start, end):
    listOfCollisions = []; listOfAllErrors = []
    j = 0

    for i in range(start, end):                                                                                         # O(n)
        parent, child = get_category_subcategory(df, i)

        try:
            cursor.execute(
                """INSERT INTO "Category_Tree" (category_id, sub_category_id) VALUES (""" + parent + """, """ + child + """)""")#, (parent, child),)     # O(n)
        except psycopg2.errors.UniqueViolation as e:
            listOfAllErrors.append(i); listOfCollisions.append(i)
        except Exception as e:
            print(f"Error occurred: {e}")
            listOfAllErrors.append(i)

        if j == 10:
            con.commit()
            j = 0  # this time we will commit for each 10th entry
        j = j + 1

    con.commit()

    print(len(listOfCollisions), len(listOfAllErrors))
    return listOfCollisions, listOfAllErrors

# %%
listOfCollisions = []
listOfAllErrors = []

# wipe the db from DBeaver

con = psycopg2.connect(database="iSupply", host="38.180.117.52", user="postgres", password="deerRun", port="5432" ); cursor = con.cursor()  # open

for i in range(2):  # first 200
    collisions, errors = process_categories(
        dfIntUnique, cursor, con, (100 * i), ((100 * i) + 100)
    )
    listOfCollisions += collisions
    listOfAllErrors += errors
    print("100 number ", (i + 1), " done")

cursor.close(); con.close()  # close
# Out:
# Error occurred: can only concatenate str (not "numpy.int32") to str
# Error occurred: can only concatenate str (not "numpy.int32") to str
# Error occurred: can only concatenate str (not "numpy.int32") to str
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 9
#       6 con = psycopg2.connect(database="iSupply", host="38.180.117.52", user="postgres", password="deerRun", port="5432" ); cursor = con.cursor()  # open
#       8 for i in range(2):  # first 200
# ----> 9     collisions, errors = process_categories(
#      10         dfIntUnique, cursor, con, (100 * i), ((100 * i) + 100)
#      11     )
#      12     listOfCollisions += collisions
#      13     listOfAllErrors += errors
#
# Cell In[49], line 12, in process_categories(df, cursor, con, start, end)
#       9 j = 0
#      11 for i in range(start, end):                                                                                         # O(n)
# ---> 12     parent, child = get_category_subcategory(df, i)
#      14     try:
#      15         cursor.execute(
#      16             """INSERT INTO "Category_Tree" (category_id, sub_category_id) VALUES (""" + parent + """, """ + child + """)""")#, (parent, child),)     # O(n)
#
# Cell In[49], line 2, in get_category_subcategory(df, index)
#       1 def get_category_subcategory(df, index):
# ----> 2     parent = df.loc[index, "category"]                                                                                  # O( log(n) )
#       3     child = df.loc[index, "subcategory"]
#       4     return parent, child
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexing.py:1146, in _LocationIndexer.__getitem__(self, key)
#    1144     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1145     if self._is_scalar_access(key):
# -> 1146         return self.obj._get_value(*key, takeable=self._takeable)
#    1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:4012, in DataFrame._get_value(self, index, col, takeable)
#    4006 engine = self.index._engine
#    4008 if not isinstance(self.index, MultiIndex):
#    4009     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4010     #  results if our categories are integers that dont match our codes
#    4011     # IntervalIndex: IntervalTree has no get_loc
# -> 4012     row = self.index.get_loc(index)
#    4013     return series._values[row]
#    4015 # For MultiIndex going through engine effectively restricts us to
#    4016 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 3

# %% [markdown]
#     Big error, lets snoop

# %%
con = psycopg2.connect(database="iSupply", host="38.180.117.52", user="postgres", password="deerRun", port="5432" ); cursor = con.cursor()  # open

parent = 12; child = -1
cursor.execute("""INSERT INTO "Category_Tree" (category_id, sub_category_id) VALUES (""" + str(parent) + """, """ + str(child) + """)""")

con.commit(); cursor.close(); con.close()  # close

# %% [markdown]
#     Don't you just love solving the problem first try, anyway lets re implement

# %%
def get_category_subcategory(df, index):
    parent = str(df.loc[index, "category"])                                                                                  # O( log(n) )
    child = str(df.loc[index, "subcategory"])
    return parent, child


def process_categories(df, cursor, con, start, end):
    listOfCollisions = []; listOfAllErrors = []
    j = 0

    for i in range(start, end):                                                                                         # O(n)
        parent, child = get_category_subcategory(df, i)

        try:
            cursor.execute(
                """INSERT INTO "Category_Tree" (category_id, sub_category_id) VALUES (""" + parent + """, """ + child + """)""")    # O(n)
        except psycopg2.errors.UniqueViolation as e:
            listOfAllErrors.append(i); listOfCollisions.append(i)
        except Exception as e:
            print(f"Error occurred: {e}")
            listOfAllErrors.append(i)

        if j == 10:
            con.commit()
            j = 0  # this time we will commit for each 10th entry
        j = j + 1

    con.commit()

    print(len(listOfCollisions), len(listOfAllErrors))
    return listOfCollisions, listOfAllErrors

# %%
listOfCollisions = []
listOfAllErrors = []

# wipe the db from DBeaver

con = psycopg2.connect(database="iSupply", host="38.180.117.52", user="postgres", password="deerRun", port="5432" ); cursor = con.cursor()  # open

for i in range(2):  # first 200
    collisions, errors = process_categories(
        dfIntUnique, cursor, con, (100 * i), ((100 * i) + 100)
    )
    listOfCollisions += collisions
    listOfAllErrors += errors
    print("100 number ", (i + 1), " done")

cursor.close(); con.close()  # close
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 9
#       6 con = psycopg2.connect(database="iSupply", host="38.180.117.52", user="postgres", password="deerRun", port="5432" ); cursor = con.cursor()  # open
#       8 for i in range(2):  # first 200
# ----> 9     collisions, errors = process_categories(
#      10         dfIntUnique, cursor, con, (100 * i), ((100 * i) + 100)
#      11     )
#      12     listOfCollisions += collisions
#      13     listOfAllErrors += errors
#
# Cell In[54], line 12, in process_categories(df, cursor, con, start, end)
#       9 j = 0
#      11 for i in range(start, end):                                                                                         # O(n)
# ---> 12     parent, child = get_category_subcategory(df, i)
#      14     try:
#      15         cursor.execute(
#      16             """INSERT INTO "Category_Tree" (category_id, sub_category_id) VALUES (""" + parent + """, """ + child + """)""")    # O(n)
#
# Cell In[54], line 2, in get_category_subcategory(df, index)
#       1 def get_category_subcategory(df, index):
# ----> 2     parent = str(df.loc[index, "category"])                                                                                  # O( log(n) )
#       3     child = str(df.loc[index, "subcategory"])
#       4     return parent, child
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexing.py:1146, in _LocationIndexer.__getitem__(self, key)
#    1144     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1145     if self._is_scalar_access(key):
# -> 1146         return self.obj._get_value(*key, takeable=self._takeable)
#    1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:4012, in DataFrame._get_value(self, index, col, takeable)
#    4006 engine = self.index._engine
#    4008 if not isinstance(self.index, MultiIndex):
#    4009     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4010     #  results if our categories are integers that dont match our codes
#    4011     # IntervalIndex: IntervalTree has no get_loc
# -> 4012     row = self.index.get_loc(index)
#    4013     return series._values[row]
#    4015 # For MultiIndex going through engine effectively restricts us to
#    4016 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 3

# %% [markdown]
#     Error remains, lets try again

# %%
def get_category_subcategory(df, index):
    parent = str(df.loc[index, "category"])                                                                                  # O( log(n) )
    child = str(df.loc[index, "subcategory"])
    return parent, child

parent, child = get_category_subcategory(dfIntUnique, 1); print(parent, child)

parent, child = get_category_subcategory(dfIntUnique, 2); print(parent, child)

parent, child = get_category_subcategory(dfIntUnique, 3); print(parent, child)
# Out:
# 2 3
# 3 -1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 10
#       6 parent, child = get_category_subcategory(dfIntUnique, 1); print(parent, child)
#       8 parent, child = get_category_subcategory(dfIntUnique, 2); print(parent, child)
# ---> 10 parent, child = get_category_subcategory(dfIntUnique, 3); print(parent, child)
#
# Cell In[58], line 2, in get_category_subcategory(df, index)
#       1 def get_category_subcategory(df, index):
# ----> 2     parent = str(df.loc[index, "category"])                                                                                  # O( log(n) )
#       3     child = str(df.loc[index, "subcategory"])
#       4     return parent, child
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexing.py:1146, in _LocationIndexer.__getitem__(self, key)
#    1144     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1145     if self._is_scalar_access(key):
# -> 1146         return self.obj._get_value(*key, takeable=self._takeable)
#    1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:4012, in DataFrame._get_value(self, index, col, takeable)
#    4006 engine = self.index._engine
#    4008 if not isinstance(self.index, MultiIndex):
#    4009     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4010     #  results if our categories are integers that dont match our codes
#    4011     # IntervalIndex: IntervalTree has no get_loc
# -> 4012     row = self.index.get_loc(index)
#    4013     return series._values[row]
#    4015 # For MultiIndex going through engine effectively restricts us to
#    4016 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 3

# %% [markdown]
#     Theres the problem, lets try this

# %%
dfIntUnique.head(10)
# Out:
#     category  subcategory
# 0          1            2
# 1          2            3
# 2          3           -1
# 4          2            4
# 5          4           -1
# 8          4            5
# 11         4            6
# 14         4            7
# 17         4            8
# 20         4            9

# %% [markdown]
#     Problem confirmed, I shall fix

# %%
dfIntUnique.reset_index(drop=True, inplace=True); dfIntUnique.size
# Out:
# 15400

# %%
dfIntUnique.head(10)
# Out:
#    category  subcategory
# 0         1            2
# 1         2            3
# 2         3           -1
# 3         2            4
# 4         4           -1
# 5         4            5
# 6         4            6
# 7         4            7
# 8         4            8
# 9         4            9

# %% [markdown]
#     Perfect, time to implement

# %%
def get_category_subcategory(df, index):
    parent = str(df.loc[index, "category"])                                                                                  # O( log(n) )
    child = str(df.loc[index, "subcategory"])
    return parent, child


def process_categories(df, cursor, con, start, end):
    listOfCollisions = []; listOfAllErrors = []
    j = 0

    for i in range(start, end):                                                                                         # O(n)
        parent, child = get_category_subcategory(df, i)

        try:
            cursor.execute(
                """INSERT INTO "Category_Tree" (category_id, sub_category_id) VALUES (""" + parent + """, """ + child + """)""")    # O(n)
        except psycopg2.errors.UniqueViolation as e:
            listOfAllErrors.append(i); listOfCollisions.append(i)
        except Exception as e:
            print(f"Error occurred: {e}")
            listOfAllErrors.append(i)

        if j == 10:
            con.commit()
            j = 0  # this time we will commit for each 10th entry
        j = j + 1

    con.commit()

    print(len(listOfCollisions), len(listOfAllErrors))
    return listOfCollisions, listOfAllErrors

# %%
listOfCollisions = []
listOfAllErrors = []

con = psycopg2.connect(database="iSupply", host="38.180.117.52", user="postgres", password="deerRun", port="5432" ); cursor = con.cursor()  # open

for i in range(2):  # first 200
    collisions, errors = process_categories(
        dfIntUnique, cursor, con, (100 * i), ((100 * i) + 100)
    )
    listOfCollisions += collisions
    listOfAllErrors += errors
    print("100 number ", (i + 1), " done")

cursor.close(); con.close()  # close
# Out:
# 0 0
# 100 number  1  done
# 0 0
# 100 number  2  done

# %% [markdown]
#     Lets cross reference with DBeaver
#
# ![DBeaver pic](DBeaverShot.PNG "Screenshot from DBeaver")

# %%
dfIntUnique.head(20)
# Out:
#     category  subcategory
# 0          1            2
# 1          2            3
# 2          3           -1
# 3          2            4
# 4          4           -1
# 5          4            5
# 6          4            6
# 7          4            7
# 8          4            8
# 9          4            9
# 10         2           10
# 11        10           -1
# 12         1           11
# 13        11           10
# 14        11           12
# 15        12           -1
# 16         1           13
# 17        13           12
# 18         1           14
# 19        14           12

# %% [markdown]
#     Perfect, time for the big one

# %%
listOfCollisions = []
listOfAllErrors = []

# wipe db

con = psycopg2.connect(database="iSupply", host="38.180.117.52", user="postgres", password="deerRun", port="5432" ); cursor = con.cursor()  # open

for i in range(154):  # first 154 00, this will take under an hour
    collisions, errors = process_categories(
        dfIntUnique, cursor, con, (100 * i), ((100 * i) + 100)
    )
    listOfCollisions += collisions
    listOfAllErrors += errors
    print("100 number ", (i + 1), " done")

cursor.close(); con.close()  # close
# Out:
# 0 0
# 100 number  1  done
# 0 0
# 100 number  2  done
# 0 0
# 100 number  3  done
# 0 0
# 100 number  4  done
# 0 0
# 100 number  5  done
# 0 0
# 100 number  6  done
# 0 0
# 100 number  7  done
# 0 0
# 100 number  8  done
# 0 0
# 100 number  9  done
# 0 0
# 100 number  10  done
# 0 0
# 100 number  11  done
# 0 0
# 100 number  12  done
# 0 0
# 100 number  13  done
# 0 0
# 100 number  14  done
# 0 0
# 100 number  15  done
# 0 0
# 100 number  16  done
# 0 0
# 100 number  17  done
# 0 0
# 100 number  18  done
# 0 0
# 100 number  19  done
# 0 0
# 100 number  20  done
# 0 0
# 100 number  21  done
# 0 0
# 100 number  22  done
# 0 0
# 100 number  23  done
# 0 0
# 100 number  24  done
# 0 0
# 100 number  25  done
# 0 0
# 100 number  26  done
# 0 0
# 100 number  27  done
# 0 0
# 100 number  28  done
# 0 0
# 100 number  29  done
# 0 0
# 100 number  30  done
# 0 0
# 100 number  31  done
# 0 0
# 100 number  32  done
# 0 0
# 100 number  33  done
# 0 0
# 100 number  34  done
# 0 0
# 100 number  35  done
# 0 0
# 100 number  36  done
# 0 0
# 100 number  37  done
# 0 0
# 100 number  38  done
# 0 0
# 100 number  39  done
# 0 0
# 100 number  40  done
# 0 0
# 100 number  41  done
# 0 0
# 100 number  42  done
# 0 0
# 100 number  43  done
# 0 0
# 100 number  44  done
# 0 0
# 100 number  45  done
# 0 0
# 100 number  46  done
# 0 0
# 100 number  47  done
# 0 0
# 100 number  48  done
# 0 0
# 100 number  49  done
# 0 0
# 100 number  50  done
# 0 0
# 100 number  51  done
# 0 0
# 100 number  52  done
# 0 0
# 100 number  53  done
# 0 0
# 100 number  54  done
# 0 0
# 100 number  55  done
# 0 0
# 100 number  56  done
# 0 0
# 100 number  57  done
# 0 0
# 100 number  58  done
# 0 0
# 100 number  59  done
# 0 0
# 100 number  60  done
# 0 0
# 100 number  61  done
# 0 0
# 100 number  62  done
# 0 0
# 100 number  63  done
# 0 0
# 100 number  64  done
# 0 0
# 100 number  65  done
# 0 0
# 100 number  66  done
# 0 0
# 100 number  67  done
# 0 0
# 100 number  68  done
# 0 0
# 100 number  69  done
# 0 0
# 100 number  70  done
# 0 0
# 100 number  71  done
# 0 0
# 100 number  72  done
# 0 0
# 100 number  73  done
# 0 0
# 100 number  74  done
# 0 0
# 100 number  75  done
# 0 0
# 100 number  76  done
# 0 0
# 100 number  77  done
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\range.py:414, in RangeIndex.get_loc(self, key)
#     413 try:
# --> 414     return self._range.index(new_key)
#     415 except ValueError as err:
#
# ValueError: 7700 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[66], line 9
#       6 con = psycopg2.connect(database="iSupply", host="38.180.117.52", user="postgres", password="deerRun", port="5432" ); cursor = con.cursor()  # open
#       8 for i in range(154):  # first 154 00, this will take under an hour
# ----> 9     collisions, errors = process_categories(
#      10         dfIntUnique, cursor, con, (100 * i), ((100 * i) + 100)
#      11     )
#      12     listOfCollisions += collisions
#      13     listOfAllErrors += errors
#
# Cell In[62], line 12, in process_categories(df, cursor, con, start, end)
#       9 j = 0
#      11 for i in range(start, end):                                                                                         # O(n)
# ---> 12     parent, child = get_category_subcategory(df, i)
#      14     try:
#      15         cursor.execute(
#      16             """INSERT INTO "Category_Tree" (category_id, sub_category_id) VALUES (""" + parent + """, """ + child + """)""")    # O(n)
#
# Cell In[62], line 2, in get_category_subcategory(df, index)
#       1 def get_category_subcategory(df, index):
# ----> 2     parent = str(df.loc[index, "category"])                                                                                  # O( log(n) )
#       3     child = str(df.loc[index, "subcategory"])
#       4     return parent, child
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexing.py:1146, in _LocationIndexer.__getitem__(self, key)
#    1144     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1145     if self._is_scalar_access(key):
# -> 1146         return self.obj._get_value(*key, takeable=self._takeable)
#    1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:4012, in DataFrame._get_value(self, index, col, takeable)
#    4006 engine = self.index._engine
#    4008 if not isinstance(self.index, MultiIndex):
#    4009     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4010     #  results if our categories are integers that dont match our codes
#    4011     # IntervalIndex: IntervalTree has no get_loc
# -> 4012     row = self.index.get_loc(index)
#    4013     return series._values[row]
#    4015 # For MultiIndex going through engine effectively restricts us to
#    4016 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\range.py:416, in RangeIndex.get_loc(self, key)
#     414         return self._range.index(new_key)
#     415     except ValueError as err:
# --> 416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
#     418     raise KeyError(key)
#
# KeyError: 7700

# %% [markdown]
#     bummer, only got 1/2 way

# %%
dfInt.iloc[7695:7705]
# Out:
#       category  subcategory
# 7695        -1         2535
# 7696      2535         2565
# 7697      2565         2568
# 7698        -1         2535
# 7699      2535         2565
# 7700      2565         2569
# 7701        -1         2535
# 7702      2535         2565
# 7703      2565         2570
# 7704        -1         2535

# %% [markdown]
#     After using the notebook for uploading in 2 halves:
#
#     "it seems any possible number in front of 7700 will hurt the code, I will inspect in the notebook"
#
#     it looks like any entry post 7700 has issues, lets see if this comes from the index

# %%
# df2 = df.iloc[7700:15400].reset_index(drop=True)

# print(df2.head())
